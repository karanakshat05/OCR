# %% [markdown]
# LOADING MODULES:
# 1. OPENCV
# 2. PILLOW
# 3. MATPLOTLIB

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# Preprocessing Steps:
# 1. inverted images
# 2. rescaling
# 3. binarisation
# 4. noise removal
# 5. dialation
# 6. rotation
# 7. removing borders
# 8. missing borders
# 9. transprency

# %% [markdown]
# # 0. opening an image
